# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('Ecommerce Customers.csv')

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.mean()
# Out:
# C:\Users\91940\AppData\Local\Temp\ipykernel_5252\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Avg. Session Length      33.053194
# Time on App              12.052488
# Time on Website          37.060445
# Length of Membership      3.533462
# Yearly Amount Spent     499.314038
# dtype: float64

# %%
df.mode()
# Out:
#                                 Email  \
# 0                   aaron04@yahoo.com
# 1                    aaron11@luna.com
# 2                   aaron22@gmail.com
# 3                   aaron89@gmail.com
# 4    acampbell@sanchez-velasquez.info
# ..                                ...
# 495            youngellen@hotmail.com
# 496                 yvaughn@meyer.com
# 497               zachary94@gmail.com
# 498                 zmalone@yahoo.com
# 499                 zscott@wright.com
#
#                                                Address       Avatar  \
# 0        0001 Mack Mill\nNorth Jennifer, NE 42021-5936    CadetBlue
# 1              001 Estrada Union\nLewismouth, TN 47360         Cyan
# 2           0013 Andre Field\nWhitebury, AZ 68447-6306  GreenYellow
# 3    0030 Mathis Square Suite 154\nSouth Jadehaven,...    SlateBlue
# 4     00615 Tracy Islands\nNew Marcfort, MO 87297-7431         Teal
# ..                                                 ...          ...
# ...

# %%
df.median()
# Out:
# C:\Users\91940\AppData\Local\Temp\ipykernel_5252\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Avg. Session Length      33.082008
# Time on App              11.983231
# Time on Website          37.069367
# Length of Membership      3.533975
# Yearly Amount Spent     498.887875
# dtype: float64

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df['Email'] = pd.to_numeric(df['Email'], errors='coerce')

# %%
df['Address'] = pd.to_numeric(df['Address'], errors='coerce')

# %%
df['Avatar'] = df['Avatar'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 0 non-null      float64
#  1   Address               0 non-null      float64
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 31.4+ KB

# %%
df
# Out:
#      Email  Address            Avatar  Avg. Session Length  Time on App  \
# 0      NaN      NaN            Violet            34.497268    12.655651
# 1      NaN      NaN         DarkGreen            31.926272    11.109461
# 2      NaN      NaN            Bisque            33.000915    11.330278
# 3      NaN      NaN       SaddleBrown            34.305557    13.717514
# 4      NaN      NaN  MediumAquaMarine            33.330673    12.795189
# ..     ...      ...               ...                  ...          ...
# 495    NaN      NaN               Tan            33.237660    13.566160
# 496    NaN      NaN     PaleVioletRed            34.702529    11.695736
# 497    NaN      NaN          Cornsilk            32.646777    11.499409
# 498    NaN      NaN              Teal            33.322501    12.391423
# 499    NaN      NaN       DarkMagenta            33.715981    12.418808
#
#      Time on Website  Length of Membership  Yearly Amount Spent
# ...

# %%
df.isnull().sum()
# Out:
# Email                   500
# Address                 500
# Avatar                    0
# Avg. Session Length       0
# Time on App               0
# Time on Website           0
# Length of Membership      0
# Yearly Amount Spent       0
# dtype: int64

# %%
print(df.loc[55])
# Out:
# Email                           NaN
# Address                         NaN
# Avatar                  GreenYellow
# Avg. Session Length       33.925297
# Time on App               11.588655
# Time on Website           35.252242
# Length of Membership        3.39205
# Yearly Amount Spent      483.673308
# Name: 55, dtype: object

# %%
df.plot(kind='scatter',x='Yearly Amount Spent',y='Length of Membership')
plt.show()

# %%
df[['Avg. Session Length','Time on App','Time on Website', 'Length of Membership','Yearly Amount Spent']]
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %%
df['Avatar'].value_counts()
# Out:
# SlateBlue               7
# Cyan                    7
# CadetBlue               7
# GreenYellow             7
# Teal                    7
#                        ..
# MediumPurple            1
# CornflowerBlue          1
# LightGoldenRodYellow    1
# PowderBlue              1
# LawnGreen               1
# Name: Avatar, Length: 138, dtype: int64

# %%
Avatar_counts = df['Avatar'].value_counts()
Avatar_counts[:8]
# Out:
# SlateBlue       7
# Cyan            7
# CadetBlue       7
# GreenYellow     7
# Teal            7
# LightSkyBlue    6
# Purple          6
# Turquoise       6
# Name: Avatar, dtype: int64

# %%
Avatar_counts[:8].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Avatar'>
